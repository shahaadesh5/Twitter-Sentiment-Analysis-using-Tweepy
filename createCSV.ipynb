# %%
import tweepy
import csv

consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
with open ('tweets_file.csv', 'w') as outfile:
    csvWriter = csv.writer(outfile)
    #tweepy cursor provides fetching of tweets with a particular keyword and number of tweets to fetch
    #keyword is realDonaldTrump and count indicates number of tweets to fetch
    for tweet in tweepy.Cursor(api.search,q="#realDonaldTrump",count=1000,
    lang="en").items(1000):
        #export the csv file with tweets and date of each tweet
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2018-10-09 22:57:35 RT @TruthSeekerQSD: #WeThePeople are now the News! Tune in LIVE to our 24/7 LiveStream -&gt; https://t.co/XQ6JOzZTuu #MSM #Qanon #RealNews #Tr…
# 2018-10-09 22:52:50 @realDonaldTrump is thinking of what day he'll sign a #realDonaldTrump Day. https://t.co/8CaqMaw6CT
# 2018-10-09 22:49:07 RT @ywb9922: @ #realdonaldtrump #泛亚  China Xinhua net and 16 banks to participate in Yunnan Fanya fraud citizens 43 billion yuan. https://t…
# 2018-10-09 22:46:54 I want u guys out of my life and networks, i have no room for u losers #davidmuir #ceciliavega u think I'm playing?… https://t.co/Q9CLxFRjlT
# 2018-10-09 22:42:07 @nikkihaley If you went into the UN every day with body armor on, that’s no respect. That’s called #Hatred. Maybe y… https://t.co/jm2ZB9eoJf
# 2018-10-09 22:35:10 Innocent?#Kavanaugh was NEVER proven innocent.#realDonaldTrump YOU HAVE 0 RIGHT to speak for… https://t.co/Zd2lItDhi2
# ...
